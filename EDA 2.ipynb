# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("CarRegisteration.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10733981 entries, 0 to 10733980
# Data columns (total 13 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   Unnamed: 0.1          int64
#  1   Unnamed: 0            int64
#  2   Country               object
#  3   Make                  object
#  4   Model                 object
#  5   Weight                float64
#  6   CO2 Emissions         float64
#  7   FuelType              object
#  8   FuelMode              object
#  9   EngineSize            float64
#  10  EnginePower           float64
#  11  Date of registration  object
#  12  Fuel consumption      float64
# dtypes: float64(5), int64(2), object(6)
# memory usage: 1.0+ GB

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 Country     Make               Model  Weight  \
# 0             0           0   Italy    TESLA             MODEL 3  1926.0
# 1             1           1   Italy     JEEP            RENEGADE  1505.0
# 2             2           2   Italy  RENAULT              TWINGO   993.0
# 3             3           3   Italy   TOYOTA  TOYOTA YARIS CROSS  1250.0
# 4             4           4   Italy  HYUNDAI                 I10   996.0
#
#    CO2 Emissions  FuelType FuelMode  EngineSize  EnginePower  \
# 0            0.0  electric        E         NaN        205.0
# 1          135.0    diesel        M      1600.0        128.0
# 2          117.0    petrol        M      1000.0         64.0
# 3          101.0    petrol        H      1500.0         91.0
# 4          116.0    petrol        M      1000.0         65.0
#
#   Date of registration  Fuel consumption
# 0           2023-03-16                NaN
# 1           2023-06-16                5.2
# ...

# %%
df.drop(columns=['Unnamed: 0', 'Unnamed: 0.1'],inplace=True)

# %%
sorted(df.Model.unique())
# Out:
# ['',
#  '#1',
#  '#3',
#  '0',
#  '001',
#  '1',
#  '107',
#  '108',
#  '114I',
#  '116 D',
#  '116 I',
#  '116 I AUT',
#  '116D',
#  '116D 5TÜRER F40 B37',
#  '116I',
#  '116I 5TÜRER F40 B38',
#  '116I BMW',
#  '116d',
#  '116i',
#  '118 D AUT',
#  '118 I',
#  '118 I AUT',
#  '118D',
#  '118D 5TÜRER F40 B47',
#  '118I',
#  '118I 5TÜRER F40 B38',
#  '118d',
#  '118i',
#  '120 I AUT',
#  '120D',
#  '120D XDRIVE',
#  '120D XDRIVE 5TÜRER F40 B47',
#  '120I',
#  '120I 5TÜRER F40 B48',
#  '120d',
#  '120d xDrive',
#  '120i',
#  '123I XDRIVE',
#  '125I',
#  '128 TI AUT',
#  '128TI',
#  '128TI 5TÜRER F40 B48',
#  '128ti',
#  '14 eDrive35',
#  '1Serie',
#  '2',
#  '2 BST Edition 230',
#  '2 BST Edition 270',
#  '2 DÖRRARS COUPE',
#  '2 HYBRID',
#  '2 Win',
#  '200',
#  '2008',
#  '2008 ACTIVE BLUEHDI 110 S&S 6 VEL MAN',
#  '2008 ACTIVE PACK BLUEHDI 130 S&S EAT8',
#  '2008 ACTIVE PACK ELECTRICO 136 (100 KW)',
#  '2008 ACTIVE PACK PURETECH 100 S&S 6 VEL MAN',
# ...

# %%
df[df['Model']== ''].index
# Out:
# Index([50745, 6474740, 6618081, 6666584, 7865055, 7871270, 7937560, 7939047,
#        7970144],
#       dtype='int64')

# %%
df.drop(df[df['Model']== ''].index, axis=0, inplace=True)

# %%
df.isna().sum()
# Out:
# Country                       0
# Make                          0
# Model                         0
# Weight                      424
# CO2 Emissions             20607
# FuelType                      0
# FuelMode                      1
# EngineSize              1670172
# EnginePower               35367
# Date of registration          0
# Fuel consumption        3182490
# dtype: int64

# %%
df.to_csv('CarRegisteration.csv')
